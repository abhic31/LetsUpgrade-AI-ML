# %% [markdown]
# # Assignment - A Company named XYZ has a problem of attrition .The rate of attrition has been quite high sobeing the head analyst of the company the repost on all the employees has been provided toyou and you need to find out the reason of attrition so the company can reduce the attrition.This is a projet that needs to be worked upon everyday as we go forward with the class and inthe end after all the test have been taught you can give a detailed report as to why there hasbeen a high rate of attrition in the company .

# %% [markdown]
# # solution:

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("general_data.csv")
dataset["Attrition"] = dataset["Attrition"].map({'No':0,'Yes':1})
dataset.head()
# Out:
#    Age  Attrition     BusinessTravel              Department  \
# 0   51          0      Travel_Rarely                   Sales
# 1   31          1  Travel_Frequently  Research & Development
# 2   32          0  Travel_Frequently  Research & Development
# 3   38          0         Non-Travel  Research & Development
# 4   32          0      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                 6          2  Life Sciences              1           1
# 1                10          1  Life Sciences              1           2
# 2                17          4          Other              1           3
# 3                 2          5  Life Sciences              1           4
# 4                10          1        Medical              1           5
#
#    Gender  ...  NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0  Female  ...                 1.0      Y                11              8
# ...

# %%
dataset.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# # lets find the mean for the data

# %%
print(dataset.mean())
# Out:
# Age                           36.923810
# Attrition                      0.161224
# DistanceFromHome               9.192517
# Education                      2.912925
# EmployeeCount                  1.000000
# EmployeeID                  2205.500000
# JobLevel                       2.063946
# MonthlyIncome              65029.312925
# NumCompaniesWorked             2.694830
# PercentSalaryHike             15.209524
# StandardHours                  8.000000
# StockOptionLevel               0.793878
# TotalWorkingYears             11.279936
# TrainingTimesLastYear          2.799320
# YearsAtCompany                 7.008163
# YearsSinceLastPromotion        2.187755
# YearsWithCurrManager           4.123129
# dtype: float64

# %%
dataset.isnull()
# Out:
#         Age  Attrition  BusinessTravel  Department  DistanceFromHome  \
# 0     False      False           False       False             False
# 1     False      False           False       False             False
# 2     False      False           False       False             False
# 3     False      False           False       False             False
# 4     False      False           False       False             False
# ...     ...        ...             ...         ...               ...
# 4405  False      False           False       False             False
# 4406  False      False           False       False             False
# 4407  False      False           False       False             False
# 4408  False      False           False       False             False
# 4409  False      False           False       False             False
#
#       Education  EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# ...

# %%
dataset.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4405    False
# 4406    False
# 4407    False
# 4408    False
# 4409    False
# Length: 4410, dtype: bool

# %%
dataset.drop_duplicates()
# Out:
#       Age  Attrition     BusinessTravel              Department  \
# 0      51          0      Travel_Rarely                   Sales
# 1      31          1  Travel_Frequently  Research & Development
# 2      32          0  Travel_Frequently  Research & Development
# 3      38          0         Non-Travel  Research & Development
# 4      32          0      Travel_Rarely  Research & Development
# ...   ...        ...                ...                     ...
# 4405   42          0      Travel_Rarely  Research & Development
# 4406   29          0      Travel_Rarely  Research & Development
# 4407   25          0      Travel_Rarely  Research & Development
# 4408   42          0      Travel_Rarely                   Sales
# 4409   40          0      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
dataset.head()
# Out:
#    Age  Attrition     BusinessTravel              Department  \
# 0   51          0      Travel_Rarely                   Sales
# 1   31          1  Travel_Frequently  Research & Development
# 2   32          0  Travel_Frequently  Research & Development
# 3   38          0         Non-Travel  Research & Development
# 4   32          0      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                 6          2  Life Sciences              1           1
# 1                10          1  Life Sciences              1           2
# 2                17          4          Other              1           3
# 3                 2          5  Life Sciences              1           4
# 4                10          1        Medical              1           5
#
#    Gender  ...  NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0  Female  ...                 1.0      Y                11              8
# ...

# %%
dataset2 = dataset.describe()
dataset2
# Out:
#                Age    Attrition  DistanceFromHome    Education  EmployeeCount  \
# count  4410.000000  4410.000000       4410.000000  4410.000000         4410.0
# mean     36.923810     0.161224          9.192517     2.912925            1.0
# std       9.133301     0.367780          8.105026     1.023933            0.0
# min      18.000000     0.000000          1.000000     1.000000            1.0
# 25%      30.000000     0.000000          2.000000     2.000000            1.0
# 50%      36.000000     0.000000          7.000000     3.000000            1.0
# 75%      43.000000     0.000000         14.000000     4.000000            1.0
# max      60.000000     1.000000         29.000000     5.000000            1.0
#
#         EmployeeID     JobLevel  MonthlyIncome  NumCompaniesWorked  \
# count  4410.000000  4410.000000    4410.000000         4391.000000
# mean   2205.500000     2.063946   65029.312925            2.694830
# ...

# %%
dataset2.median()
dataset
# Out:
#       Age  Attrition     BusinessTravel              Department  \
# 0      51          0      Travel_Rarely                   Sales
# 1      31          1  Travel_Frequently  Research & Development
# 2      32          0  Travel_Frequently  Research & Development
# 3      38          0         Non-Travel  Research & Development
# 4      32          0      Travel_Rarely  Research & Development
# ...   ...        ...                ...                     ...
# 4405   42          0      Travel_Rarely  Research & Development
# 4406   29          0      Travel_Rarely  Research & Development
# 4407   25          0      Travel_Rarely  Research & Development
# 4408   42          0      Travel_Rarely                   Sales
# 4409   40          0      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
dataset2.mode()
dataset2
# Out:
#                Age    Attrition  DistanceFromHome    Education  EmployeeCount  \
# count  4410.000000  4410.000000       4410.000000  4410.000000         4410.0
# mean     36.923810     0.161224          9.192517     2.912925            1.0
# std       9.133301     0.367780          8.105026     1.023933            0.0
# min      18.000000     0.000000          1.000000     1.000000            1.0
# 25%      30.000000     0.000000          2.000000     2.000000            1.0
# 50%      36.000000     0.000000          7.000000     3.000000            1.0
# 75%      43.000000     0.000000         14.000000     4.000000            1.0
# max      60.000000     1.000000         29.000000     5.000000            1.0
#
#         EmployeeID     JobLevel  MonthlyIncome  NumCompaniesWorked  \
# count  4410.000000  4410.000000    4410.000000         4391.000000
# mean   2205.500000     2.063946   65029.312925            2.694830
# ...

# %%
dataset2.var()
# Out:
# Age                        2.394681e+06
# Attrition                  2.430772e+06
# DistanceFromHome           2.420030e+06
# Education                  2.428033e+06
# EmployeeCount              2.430068e+06
# EmployeeID                 2.525177e+06
# JobLevel                   2.428626e+06
# MonthlyIncome              3.857002e+09
# NumCompaniesWorked         2.406795e+06
# PercentSalaryHike          2.415503e+06
# StandardHours              2.423466e+06
# StockOptionLevel           2.429967e+06
# TotalWorkingYears          2.407106e+06
# TrainingTimesLastYear      2.428167e+06
# YearsAtCompany             2.420136e+06
# YearsSinceLastPromotion    2.427193e+06
# YearsWithCurrManager       2.425264e+06
# dtype: float64

# %%
dataset2.skew()
# Out:
# Age                        2.827868
# Attrition                  2.828427
# DistanceFromHome           2.828249
# Education                  2.828423
# EmployeeCount              2.828427
# EmployeeID                 0.068262
# JobLevel                   2.828423
# MonthlyIncome              1.860748
# NumCompaniesWorked         2.828410
# PercentSalaryHike          2.828341
# StandardHours              2.828409
# StockOptionLevel           2.828425
# TotalWorkingYears          2.828096
# TrainingTimesLastYear      2.828420
# YearsAtCompany             2.828061
# YearsSinceLastPromotion    2.828372
# YearsWithCurrManager       2.828364
# dtype: float64

# %%
dataset2.kurt()
# Out:
# Age                        7.997628
# Attrition                  7.999999
# DistanceFromHome           7.999241
# Education                  7.999981
# EmployeeCount              7.999999
# EmployeeID                -1.084610
# JobLevel                   7.999982
# MonthlyIncome              4.104953
# NumCompaniesWorked         7.999927
# PercentSalaryHike          7.999633
# StandardHours              7.999922
# StockOptionLevel           7.999991
# TotalWorkingYears          7.998588
# TrainingTimesLastYear      7.999971
# YearsAtCompany             7.998440
# YearsSinceLastPromotion    7.999767
# YearsWithCurrManager       7.999733
# dtype: float64

# %%
dataset2
# Out:
#                Age    Attrition  DistanceFromHome    Education  EmployeeCount  \
# count  4410.000000  4410.000000       4410.000000  4410.000000         4410.0
# mean     36.923810     0.161224          9.192517     2.912925            1.0
# std       9.133301     0.367780          8.105026     1.023933            0.0
# min      18.000000     0.000000          1.000000     1.000000            1.0
# 25%      30.000000     0.000000          2.000000     2.000000            1.0
# 50%      36.000000     0.000000          7.000000     3.000000            1.0
# 75%      43.000000     0.000000         14.000000     4.000000            1.0
# max      60.000000     1.000000         29.000000     5.000000            1.0
#
#         EmployeeID     JobLevel  MonthlyIncome  NumCompaniesWorked  \
# count  4410.000000  4410.000000    4410.000000         4391.000000
# mean   2205.500000     2.063946   65029.312925            2.694830
# ...

# %% [markdown]
# ## From the above data we can conclude:
# # 1. All data show positive skewness
# # 2. Employeeid is platokurtic while others are mesokurtic and leptokurtic
# # 3. mean,median mode is calculate the average of data

# %%
box_plot = dataset.Age
plt.boxplot(box_plot)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2d0d2629588>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2d0d2644f08>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2d0d2634f08>],
#  'medians': [<matplotlib.lines.Line2D at 0x2d0d264cdc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2d0d264cec8>],
#  'means': []}

# %% [markdown]
# # we conclude that age is normally disturbted without any outliers

# %%
box_plot = dataset.MonthlyIncome
plt.boxplot(box_plot)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2d0d26d32c8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2d0d26e4d88>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2d0d26e2ac8>],
#  'medians': [<matplotlib.lines.Line2D at 0x2d0d26e9e48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2d0d26ede48>],
#  'means': []}

# %% [markdown]
# # we conclude that we have outliers in monthly income data

# %%
box_plot = dataset.DistanceFromHome
plt.boxplot(box_plot)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2d0d3fe3e48>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2d0d446cf48>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2d0d4466448>],
#  'medians': [<matplotlib.lines.Line2D at 0x2d0d4471a48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2d0d4476a48>],
#  'means': []}

# %% [markdown]
# # we conclude that there is no outliers

# %%
dataset.head()
# Out:
#    Age  Attrition     BusinessTravel              Department  \
# 0   51          0      Travel_Rarely                   Sales
# 1   31          1  Travel_Frequently  Research & Development
# 2   32          0  Travel_Frequently  Research & Development
# 3   38          0         Non-Travel  Research & Development
# 4   32          0      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                 6          2  Life Sciences              1           1
# 1                10          1  Life Sciences              1           2
# 2                17          4          Other              1           3
# 3                 2          5  Life Sciences              1           4
# 4                10          1        Medical              1           5
#
#    Gender  ...  NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0  Female  ...                 1.0      Y                11              8
# ...

# %% [markdown]
# # Attrition vs age

# %%
from scipy.stats import mannwhitneyu
a1 = dataset.Attrition
a2 = dataset.Age
stat, p=mannwhitneyu(a1,a2)
print(stat, p)
# Out:
# 0.0 0.0

# %% [markdown]
# # Attrition vs Distance from home

# %%
from scipy.stats import mannwhitneyu
a1 = dataset.Attrition
a2 = dataset.DistanceFromHome
stat, p=mannwhitneyu(a1,a2)
print(stat, p)
# Out:
# 221832.0 0.0

# %% [markdown]
# # Attrition vs employee id

# %%
from scipy.stats import mannwhitneyu
a1 = dataset.Attrition
a2 = dataset.EmployeeID
stat, p=mannwhitneyu(a1,a2)
print(stat, p)

# %% [markdown]
# # Attrition vs numcompanies worked

# %%
from scipy.stats import mannwhitneyu
a1 = dataset.Attrition
a2 = dataset.NumCompaniesWorked
stat, p=mannwhitneyu(a1,a2)
print(stat, p)

# %% [markdown]
# # Attrition vs percentsalaryhike

# %%
from scipy.stats import mannwhitneyu
a1 = dataset.Attrition
a2 = dataset.PercentSalaryHike
stat, p=mannwhitneyu(a1,a2)
print(stat, p)

# %% [markdown]
# #  Attrition vs std hours

# %%
from scipy.stats import mannwhitneyu
a1 = dataset.Attrition
a2 = dataset.StandardHours
stat, p=mannwhitneyu(a1,a2)
print(stat, p)

# %% [markdown]
# # Attrition vs total work hours

# %%
from scipy.stats import mannwhitneyu
a1 = dataset.Attrition
a2 = dataset.TotalWorkingYears
stat, p=mannwhitneyu(a1,a2)
print(stat, p)
